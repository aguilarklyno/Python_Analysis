# %%
# Pythonの検索パスにディレクトリを追加
import sys
sys.path.append('./functions')

# datacollect.pyからgreet関数をインポート
from datacollect import get_yfinanceInfo
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
import yfinance as yf

def get_yfinanceInfo(tickers_list):
    """
    複数のティッカーコードに対応するyfinance.Tickerオブジェクトを取得する。
    :param ticker_codes: ティッカーコードのリスト
    :return: 各ティッカーコードに対応するyfinance.Tickerオブジェクトの辞書
    """
    tickers = {}
    for code in tickers_list:
        tickers[code] = yf.Ticker(code)
    return tickers

# %%
tickers = ["9984.T", "MSFT"]

temp = get_yfinanceInfo(tickers)
temp
# Out:
# {'9984.T': yfinance.Ticker object <9984.T>,
#  'MSFT': yfinance.Ticker object <MSFT>}

# %%
temp['9984.T'].info
# Out:
# {'address1': '1-7-1, Kaigan',
#  'address2': 'Minato-ku',
#  'city': 'Tokyo',
#  'zip': '105-7537',
#  'country': 'Japan',
#  'phone': '81 3 6889 2000',
#  'website': 'https://group.softbank',
#  'industry': 'Telecom Services',
#  'industryKey': 'telecom-services',
#  'industryDisp': 'Telecom Services',
#  'sector': 'Communication Services',
#  'sectorKey': 'communication-services',
#  'sectorDisp': 'Communication Services',
# ...
