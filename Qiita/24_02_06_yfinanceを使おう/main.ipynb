# %%
import yfinance as yf

appl = yf.Ticker("AAPL")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
appl
# Out:
# yfinance.Ticker object <AAPL>

# %%
# get all stock info
appl.info
# Out:
# {'trailingPegRatio': 2.3244}

# %%
appl.info['financialCurrency']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 appl.info['financialCurrency']
#
# KeyError: 'financialCurrency'

# %%
# get historical market data
hist = appl.history(period="1mo")
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-10 00:00:00-05:00  184.115062  186.162437  183.685602  185.952713
# 2024-01-11 00:00:00-05:00  186.302271  186.811631  183.385994  185.353485
# 2024-01-12 00:00:00-05:00  185.822881  186.502022  184.953994  185.683060
# 2024-01-16 00:00:00-05:00  181.927853  184.025168  180.699410  183.395981
# 2024-01-17 00:00:00-05:00  181.038998  182.696871  180.070233  182.447189
# 2024-01-18 00:00:00-05:00  185.852846  188.898962  185.593183  188.389618
# 2024-01-19 00:00:00-05:00  189.088718  191.705375  188.579374  191.315872
# 2024-01-22 00:00:00-05:00  192.054929  195.081066  192.014971  193.642899
# 2024-01-23 00:00:00-05:00  194.771475  195.500540  193.582989  194.931259
# 2024-01-24 00:00:00-05:00  195.170947  196.129730  194.092321  194.252121
# 2024-01-25 00:00:00-05:00  194.971211  196.019876  192.863900  193.922546
# 2024-01-26 00:00:00-05:00  194.022423  194.511788  191.695390  192.174774
# ...

# %%
# show meta information about the history (requires history() to be called first)
appl.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'AAPL',
#  'exchangeName': 'NMS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 345479400,
#  'regularMarketTime': 1707426001,
#  'gmtoffset': -18000,
#  'timezone': 'EST',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 188.32,
#  'chartPreviousClose': 185.56,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EST',
#    'start': 1707382800,
#    'end': 1707402600,
#    'gmtoffset': -18000},
#   'regular': {'timezone': 'EST',
#    'start': 1707402600,
#    'end': 1707426000,
#    'gmtoffset': -18000},
#   'post': {'timezone': 'EST',
#    'start': 1707426000,
#    'end': 1707440400,
#    'gmtoffset': -18000}},
#  'dataGranularity': '1d',
#  'range': '1mo',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
# show actions (dividends, splits, capital gains)
appl.actions
appl.dividends
appl.splits
appl.capital_gains
# Out:
# Series([], dtype: object)

# %%
# show share count
appl.get_shares_full(start="2022-01-01", end=None)
# Out:
# 2022-01-10 00:00:00-05:00    16334399488
# 2022-01-31 00:00:00-05:00    16319399936
# 2022-02-04 00:00:00-05:00    16319399936
# 2022-02-05 00:00:00-05:00    16319399936
# 2022-02-11 00:00:00-05:00    16319399936
#                                 ...
# 2024-01-16 00:00:00-05:00    15462700032
# 2024-01-16 00:00:00-05:00    15461900288
# 2024-02-01 00:00:00-05:00    15461900288
# 2024-02-01 00:00:00-05:00    15770500096
# 2024-02-03 00:00:00-05:00    15441899520
# Length: 101, dtype: int64

# %%
# show financials:
# - income statement\n
appl.income_stmt
appl.quarterly_income_stmt
# Out:
#                                                         2023-12-31  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                           0.159
# Normalized EBITDA                                    43221000000.0
# Net Income From Continuing Operation Net Minori...   33916000000.0
# Reconciled Depreciation                               2848000000.0
# Reconciled Cost Of Revenue                           64720000000.0
# EBITDA                                               43221000000.0
# EBIT                                                 40373000000.0
# Net Interest Income                                            NaN
# Interest Expense                                               NaN
# Interest Income                                                NaN
# Normalized Income                                    33916000000.0
# Net Income From Continuing And Discontinued Ope...   33916000000.0
# ...

# %%
# - balance sheet
appl.balance_sheet
appl.quarterly_balance_sheet
# Out:
#                                                       2023-12-31  \
# Treasury Shares Number                                       0.0
# Ordinary Shares Number                             15460223000.0
# Share Issued                                       15460223000.0
# Net Debt                                           67280000000.0
# Total Debt                                        108040000000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments   73100000000.0
# Other Short Term Investments                       32340000000.0
# Cash And Cash Equivalents                          40760000000.0
# Cash Equivalents                                   11218000000.0
# Cash Financial                                     29542000000.0
#
#                                                       2023-09-30  \
# Treasury Shares Number                                       0.0
# ...

# %%
# - cash flow statement
appl.cashflow
appl.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options
# Out:
#                                                    2023-12-31     2023-09-30  \
# Free Cash Flow                                  37503000000.0  19435000000.0
# Repurchase Of Capital Stock                    -20139000000.0 -21003000000.0
# Repayment Of Debt                               -3984000000.0            0.0
# Issuance Of Debt                                          NaN            0.0
# Capital Expenditure                             -2392000000.0  -2163000000.0
# Interest Paid Supplemental Data                           NaN   1213000000.0
# Income Tax Paid Supplemental Data                7255000000.0  11659000000.0
# End Cash Position                               41974000000.0  30737000000.0
# Beginning Cash Position                         30737000000.0  29898000000.0
# Changes In Cash                                 11237000000.0    839000000.0
# Financing Cash Flow                            -30585000000.0 -23153000000.0
# ...

# %%
appl.get_income_stmt()
# Out:
#                                                         2023-09-30  \
# TaxEffectOfUnusualItems                                        0.0
# TaxRateForCalcs                                              0.147
# NormalizedEBITDA                                    129188000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   96995000000.0
# ReconciledDepreciation                               11519000000.0
# ReconciledCostOfRevenue                             214137000000.0
# EBITDA                                              129188000000.0
# EBIT                                                117669000000.0
# NetInterestIncome                                     -183000000.0
# InterestExpense                                       3933000000.0
# InterestIncome                                        3750000000.0
# NormalizedIncome                                     96995000000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      96995000000.0
# ...

# %%
# show holders
appl.major_holders
appl.institutional_holders
appl.mutualfund_holders
appl.insider_transactions
appl.insider_purchases
appl.insider_roster_holders
# Out:
#                 Name         Position URL  \
# 0  ADAMS KATHERINE L  General Counsel
# 1       BELL JAMES A         Director
# 2   GORE ALBERT A JR         Director
# 3        GORSKY ALEX         Director
# 4        JUNG ANDREA         Director
# 5  KONDO CHRISTOPHER          Officer
# 6  LEVINSON ARTHUR D         Director
# 7   LOZANO MONICA C.         Director
# 8     SUGAR RONALD D         Director
# 9     WAGNER SUSAN L         Director
#
#                          Most Recent Transaction Latest Transaction Date  \
# 0                                           Sale              2023-11-17
# 1  Conversion of Exercise of derivative security              2024-02-01
# 2  Conversion of Exercise of derivative security              2024-02-01
# 3  Conversion of Exercise of derivative security              2024-02-01
# 4  Conversion of Exercise of derivative security              2024-02-01
# 5                                           Sale              2023-11-29
# ...

# %%
# show recommendations
appl.recommendations
appl.recommendations_summary
appl.upgrades_downgrades
# Out:
#                                   Firm      ToGrade    FromGrade Action
# GradeDate
# 2024-02-02 20:29:37          JP Morgan   Overweight   Overweight   main
# 2024-02-02 18:02:06        Oppenheimer   Outperform   Outperform   reit
# 2024-02-02 13:49:30            Wedbush   Outperform   Outperform   reit
# 2024-02-02 12:44:37           Barclays  Underweight  Underweight   main
# 2024-02-02 12:14:28            Needham          Buy          Buy   reit
# ...                                ...          ...          ...    ...
# 2012-03-14 12:21:00  Canaccord Genuity          Buy                main
# 2012-03-14 10:13:00     Morgan Stanley   Overweight                main
# 2012-03-13 10:08:00          Jefferies          Buy                main
# 2012-03-08 12:33:00     FBN Securities   Outperform                main
# 2012-02-09 13:17:00  Canaccord Genuity          Buy                main
#
# [1022 rows x 4 columns]

# %%
# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default. 
# Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
appl.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-01-30 16:00:00-05:00           NaN           NaN          NaN
# 2024-10-31 06:00:00-04:00           NaN           NaN          NaN
# 2024-08-01 06:00:00-04:00           NaN           NaN          NaN
# 2024-05-02 06:00:00-04:00          1.51           NaN          NaN
# 2024-02-01 16:00:00-05:00          2.10          2.18       0.0396
# 2024-01-31 05:00:00-05:00          2.10          2.18       0.0381
# 2023-11-02 16:00:00-04:00          1.39          1.46       0.0492
# 2023-08-03 16:00:00-04:00          1.19          1.26       0.0549
# 2023-05-04 16:00:00-04:00          1.43          1.52       0.0603
# 2023-02-02 16:00:00-05:00          1.94          1.88      -0.0288
# 2022-10-27 16:00:00-04:00          1.27          1.29       0.0155
# 2022-07-28 16:00:00-04:00          1.16          1.20       0.0325

# %%
# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
appl.isin
# Out:
# 'US0378331005'

# %%
# show options expirations
appl.options
# Out:
# ('2024-02-09',
#  '2024-02-16',
#  '2024-02-23',
#  '2024-03-01',
#  '2024-03-08',
#  '2024-03-15',
#  '2024-03-22',
#  '2024-04-19',
#  '2024-05-17',
#  '2024-06-21',
#  '2024-07-19',
#  '2024-08-16',
#  '2024-09-20',
#  '2024-12-20',
#  '2025-01-17',
#  '2025-03-21',
#  '2025-06-20',
#  '2025-09-19',
#  '2025-12-19',
#  '2026-01-16',
#  '2026-06-18')

# %%
# show news
appl.news
# Out:
# [{'uuid': '00085c3f-724a-39ca-aa21-d383d5c5ef58',
#   'title': 'Here are my favorite Vision Pro apps (so far)',
#   'publisher': 'TechCrunch',
#   'link': 'https://finance.yahoo.com/m/00085c3f-724a-39ca-aa21-d383d5c5ef58/here-are-my-favorite-vision.html',
#   'providerPublishTime': 1707436280,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/jvOMriS3vWCqZxjZJlY.EA--~B/aD0xMzUwO3c9MjQwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/techcrunch_for_finance_733/fd373aec835359acf5c935e81122a73a',
#      'width': 2400,
#      'height': 1350,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/V3a18BNf0FCGTZBB3apaYA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/techcrunch_for_finance_733/fd373aec835359acf5c935e81122a73a',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['AAPL']},
# ...

# %%
# get option chain for specific expiration
opt = appl.option_chain('2024-02-23')
opt.calls
# data available via: opt.calls, opt.puts
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   AAPL240223C00100000 2024-01-30 15:44:16+00:00   100.0      89.33  87.95
# 1   AAPL240223C00110000 2024-01-22 17:07:40+00:00   110.0      83.50  78.00
# 2   AAPL240223C00120000 2024-01-22 14:56:30+00:00   120.0      75.00  68.00
# 3   AAPL240223C00130000 2024-01-29 20:16:12+00:00   130.0      62.10  58.05
# 4   AAPL240223C00140000 2024-01-19 14:58:50+00:00   140.0      50.00  48.10
# 5   AAPL240223C00145000 2024-02-08 20:41:42+00:00   145.0      43.32  43.10
# 6   AAPL240223C00150000 2024-02-05 15:24:30+00:00   150.0      37.00  38.15
# 7   AAPL240223C00155000 2024-02-07 19:50:19+00:00   155.0      34.50  33.15
# 8   AAPL240223C00160000 2024-02-08 20:24:59+00:00   160.0      28.52  28.25
# 9   AAPL240223C00165000 2024-02-07 20:18:00+00:00   165.0      24.45  23.25
# 10  AAPL240223C00170000 2024-02-08 17:54:34+00:00   170.0      18.40  18.30
# ...

# %%
temp = yf.download('APPL')
temp
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['APPL']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1925-03-04 -> 2024-02-08)')
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
import yfinance as yf
data = yf.download("AAPL GOOG MSFT", period="1mo")
data
# Out:
# [*********************100%%**********************]  3 of 3 completed
# Price        Adj Close                               Close              \
# Ticker            AAPL        GOOG        MSFT        AAPL        GOOG
# Date
# 2024-01-09  185.139999  142.559998  375.790009  185.139999  142.559998
# 2024-01-10  186.190002  143.800003  382.769989  186.190002  143.800003
# 2024-01-11  185.589996  143.669998  384.630005  185.589996  143.669998
# 2024-01-12  185.919998  144.240005  388.470001  185.919998  144.240005
# 2024-01-16  183.630005  144.080002  390.269989  183.630005  144.080002
# 2024-01-17  182.679993  142.889999  389.470001  182.679993  142.889999
# 2024-01-18  188.630005  144.990005  393.869995  188.630005  144.990005
# 2024-01-19  191.559998  147.970001  398.670013  191.559998  147.970001
# 2024-01-22  193.889999  147.710007  396.510010  193.889999  147.710007
# 2024-01-23  195.179993  148.679993  398.899994  195.179993  148.679993
# ...

# %%
import yfinance as yf
yf.set_tz_cache_location("custom/cache/location")
